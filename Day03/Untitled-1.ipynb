# %%
bank="512941235"

# %%
banklast="12351259"

# %%
bankfirst="95123723"

# %%
digits=["9", "8", "7", "6", "5", "4", "3", "2", "1"]

# %%
digits=["9", "8", "7", "6", "5", "4", "3", "2", "1", "0"]

# %%
banksame="555"

# %%
for d in digits:
    bank.find(d)
    print(d)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for d in digits:
    i=bank.find(d)
    print(i)
# Out:
# 3
# -1
# -1
# -1
# 0
# 4
# 7
# 2
# 1
# -1

# %%
for d in digits:
    i=bank.find(d)
    print(i)
    print(f'first num: {bank[i]}')
# Out:
# 3
# first num: 9
# -1
# first num: 5
# -1
# first num: 5
# -1
# first num: 5
# 0
# first num: 5
# 4
# first num: 4
# 7
# first num: 3
# 2
# first num: 2
# 1
# first num: 1
# -1
# first num: 5

# %%
c=0
for d in digits:
    i=bank.find(d)
    print(i)
    print(f'first num: {bank[i]}')
    c += 1
    if c == 2: break
# Out:
# 3
# first num: 9
# -1
# first num: 5

# %%
c=0
bank_remainder=bank
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'first num: {bank[i]}')
    bank_remainder = bank_remainder[i:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: break
# Out:
# 3
# first num: 9
# leaves: 941235
# -1
# first num: 5
# leaves: 5

# %%
c=0
bank_remainder=bank
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'first num: {bank[i]}')
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: break
# Out:
# 3
# first num: 9
# leaves: 41235
# -1
# first num: 5
# leaves: 41235

# %%
c=0
joltage=''
bank_remainder=bank
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'highest num: {bank[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 3
# highest num: 9
# leaves: 41235
# -1
# highest num: 5
# leaves: 41235
# 95

# %%
c=0
joltage=''
bank_remainder=bank
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'highest num: {bank[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 3
# highest num: 9
# leaves: 41235
# -1
# highest num: 5
# leaves: 41235
# 95

# %%
c=0
joltage=''
bank_remainder=banklast
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'highest num: {bank[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 7
# highest num: 3
# leaves:
# -1
# highest num: 5
# leaves:
# 35

# %%
c=0
joltage=''
bank_remainder=banklast
for d in digits:
    i=bank_remainder.find(d)
    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 7
# highest num: 9
# leaves:
# -1
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 7, in <module>
# IndexError: string index out of range

# %%
c=0
joltage=''
bank_remainder=banklast
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder):
        break

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 7
# highest num: 9
# leaves:
# -1
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 11, in <module>
# IndexError: string index out of range

# %%
c=0
joltage=''
bank_remainder=banklast
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder) - 1:
        break

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break

# %%
c=0
joltage=''
bank_remainder=banklast
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder) - 1:
        continue

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# -1
# highest num: 9
# leaves: 12351259
# -1
# highest num: 9
# leaves: 12351259
# 55

# %%
c=0
joltage=''
bank_remainder=bankfirst
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder) - 1:
        continue

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 0
# highest num: 9
# leaves: 5123723
# -1
# highest num: 3
# leaves: 5123723
# 55

# %%
c=0
joltage=''
bank_remainder=bankfirst
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder) - 1:
        continue

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 0
# highest num: 9
# leaves: 5123723
# -1
# highest num: 3
# leaves: 5123723
# 93

# %%
c=0
joltage=''
bank_remainder=bankfirst
print(bank_remainder)
for d in digits:
    i=bank_remainder.find(d)
    
    if i == len(bank_remainder) - 1:
        continue

    print(i)
    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 95123723
# 0
# highest num: 9
# leaves: 5123723
# -1
# highest num: 3
# leaves: 5123723
# 93

# %%
c=0
joltage=''
bank_remainder=bankfirst
print(bank_remainder)
for d in digits:
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
# Out:
# 95123723
# highest num: 9
# leaves: 5123723
# highest num: 7
# leaves: 23
# 97

# %%
c=0
joltage=''
bank_remainder=bankfirst
print(bank_remainder)
for d in digits:
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    print(f'leaves: {bank_remainder}')
    c += 1
    if c == 2: print(joltage); break
    print(f'leaves: {bank_remainder}')
# Out:
# 95123723
# highest num: 9
# leaves: 5123723
# leaves: 5123723
# highest num: 7
# leaves: 23
# 97

# %%
c=0
joltage=''
bank_remainder=bankfirst
print(bank_remainder)
for d in digits:
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    if c == 2: print(joltage); break
    print(f'leaves: {bank_remainder}')
# Out:
# 95123723
# highest num: 9
# leaves: 5123723
# highest num: 7
# 97

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
for d in digits:
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    if c == 2: print(joltage); break
    print(f'leaves: {bank_remainder}')
# Out:
# 12351259
# hit last…
# highest num: 5
# leaves: 1259
# highest num: 2
# 52

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)


for d in digits:
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    if c == 2: print(joltage); break
    print(f'leaves: {bank_remainder}')
# Out:
# 12351259
# hit last…
# highest num: 5
# leaves: 1259
# highest num: 2
# 52

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop()
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    
print(joltage)
# Out:
# 12351259
# highest num: 1
# leaves: 2351259
# highest num: 2
# leaves: 351259
# 12

# %%
digi
# Out:
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'digi' is not defined. Did you mean: 'digits'?

# %%
digits_remainder
# Out:
# ['9', '8', '7', '6', '5', '4', '3']

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    
print(joltage)
# Out:
# 12351259
# hit last…
# highest num: 5
# leaves: 1259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
digits
# Out:
# []

# %%
digits=["9", "8", "7", "6", "5", "4", "3", "2", "1"]

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# hit last…
# highest num: 5
# leaves: 1259
# highest num: 2
# leaves: 59
# 52

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# highest num: 1
# leaves: 2351259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits.copy()

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 8, in <module>
# IndexError: pop from empty list

# %%
digits
# Out:
# []

# %%
digits=["9", "8", "7", "6", "5", "4", "3", "2", "1", "0"]

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits.copy()

while c != 2:
    d = digits_remainder.pop(0)
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# hit last…
# hit last…
# highest num: 5
# leaves: 1259
# highest num: 2
# leaves: 59
# 52

# %%
c=0
joltage=''
bank_remainder=banklast
print(bank_remainder)
digits_remainder=digits

while c != 2:
    d = digits_remainder[0]
    digits_remainder = digits_remainder[1:]
    i=bank_remainder.find(d)
    if i == -1: continue

    if i == len(bank_remainder) - 1:
        print('hit last…')
        digits_remainder=digits
        continue

    print(f'highest num: {bank_remainder[i]}')
    joltage += bank_remainder[i]
    bank_remainder = bank_remainder[i+1:]
    c += 1
    print(f'leaves: {bank_remainder}')
    digits_remainder=digits
    
print(joltage)
# Out:
# 12351259
# highest num: 1
# leaves: 2351259
# highest num: 1
# leaves: 259
# 11

# %%
digits
# Out:
# ['1', '0']

# %%
digits=["9", "8", "7", "6", "5", "4", "3", "2", "1", "0"]

# %%
digits
# Out:
# ['9', '8', '7', '6', '5', '4', '3', '2', '1', '0']

# %%
d = digits_remainder[0]

# %%
d
# Out:
# 8

# %%
digits
# Out:
# ['9', '8', '7', '6', '5', '4', '3', '2', '1', '0']

# %%
digi
# Out:
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'digi' is not defined. Did you mean: 'digits'?

# %%
digits_remainder
# Out:
# ['8', '7', '6', '5', '4', '3', '2', '1', '0']

# %%
digits_remainder=digits

# %%
digi
# Out:
# Traceback (most recent call last):
#   File "/Users/marcel/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'digi' is not defined. Did you mean: 'digits'?

# %%
digits_remainder
# Out:
# ['9', '8', '7', '6', '5', '4', '3', '2', '1', '0']

# %%
d = digits_remainder[0]

# %%
d
# Out:
# 9

# %%
digits_remainder = digits_remainder[1:]

# %%
digits_remainder
# Out:
# ['8', '7', '6', '5', '4', '3', '2', '1', '0']
